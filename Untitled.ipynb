# %%
import matplotlib.pyplot as plt
X=[2,3]
Y=[8,5]
plt.plot(X,Y)
plt.show()

# %%
import matplotlib.pyplot as plt
X=[2,3]
Y=[8,5]
X1=[6,7]
Y1=[9,5]
plt.plot(X,Y)
plt.plot(X1,Y1)
plt.show()

# %%
import matplotlib.pyplot as plt
X=[2,3]
Y=[8,5]
#X1=[6,7]
#Y1=[9,5]
plt.bar(X,Y)
#plt.plot(X1,Y1)
plt.show()

# %%
import matplotlib.pyplot as plt
X=[2,3]
Y=[8,5]
#X1=[6,7]
#Y1=[9,5]
plt.scatter(X,Y,label =c='r',s=150,marker='x')
plt.xlabel('time')
plt.ylabel('speed')
#plt.plot(X1,Y1)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
